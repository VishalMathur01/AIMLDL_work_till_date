# %%
import pandas as pd
import requests as rq

# %%
import requests

url = "https://bloomberg-market-and-financial-news.p.rapidapi.com/stories/list"

querystring = {"template":"CURRENCY","id":"usdjpy"}

headers = {
	"X-RapidAPI-Key": "d0d5b4c390msh1b9e671fe6b1ebcp1767eejsn31408039d516",
	"X-RapidAPI-Host": "bloomberg-market-and-financial-news.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'stories': [{'resourceType': 'Story', 'card': 'article', 'title': 'Ringgit Bulls Watch Central Bank Support as Neighbors Hike Rates', 'published': 1698624192, 'internalID': 'S34DXNDWRGG001', 'thumbnailImage': 'https://assets.bwbx.io/images/users/iqjWHBFdfxIU/iSCpVyRgzys4/v0/600x-1.jpg', 'primarySite': 'markets', 'shortURL': 'https://www.bloomberg.com/news/articles/2023-10-30/ringgit-bulls-watch-central-bank-support-as-neighbors-hike-rates', 'longURL': 'https://www.bloomberg.com/news/articles/2023-10-30/ringgit-bulls-watch-central-bank-support-as-neighbors-hike-rates'}, {'resourceType': 'Story', 'card': 'article', 'title': 'Ueda Faces Fallout Risk as BOJ Mulls Yields, Prices, Yen', 'published': 1698637898, 'internalID': 'S2YG04T0G1KW01', 'label': 'Central Banks', 'thumbnailImage': 'https://assets.bwbx.io/images/users/iqjWHBFdfxIU/iugCJiBxIKF8/v1/600x-1.jpg', 'primarySite': 'economics', 'shortURL': 'https://www.bloomberg.com/news/articles/2023-10-29/ueda-faces-market-fallout-risk-as-b
# ...

# %%
import requests

url = "https://bloomberg-market-and-financial-news.p.rapidapi.com/stories/list"

querystring = {"template":"CURRENCY","id":"usdjpy"}

headers = {
	"X-RapidAPI-Key": "d0d5b4c390msh1b9e671fe6b1ebcp1767eejsn31408039d516",
	"X-RapidAPI-Host": "bloomberg-market-and-financial-news.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'stories': [{'resourceType': 'Story', 'card': 'article', 'title': 'Ringgit Bulls Watch Central Bank Support as Neighbors Hike Rates', 'published': 1698624192, 'internalID': 'S34DXNDWRGG001', 'thumbnailImage': 'https://assets.bwbx.io/images/users/iqjWHBFdfxIU/iSCpVyRgzys4/v0/600x-1.jpg', 'primarySite': 'markets', 'shortURL': 'https://www.bloomberg.com/news/articles/2023-10-30/ringgit-bulls-watch-central-bank-support-as-neighbors-hike-rates', 'longURL': 'https://www.bloomberg.com/news/articles/2023-10-30/ringgit-bulls-watch-central-bank-support-as-neighbors-hike-rates'}, {'resourceType': 'Story', 'card': 'article', 'title': 'Ueda Faces Fallout Risk as BOJ Mulls Yields, Prices, Yen', 'published': 1698637898, 'internalID': 'S2YG04T0G1KW01', 'label': 'Central Banks', 'thumbnailImage': 'https://assets.bwbx.io/images/users/iqjWHBFdfxIU/iugCJiBxIKF8/v1/600x-1.jpg', 'primarySite': 'economics', 'shortURL': 'https://www.bloomberg.com/news/articles/2023-10-29/ueda-faces-market-fallout-risk-as-b
# ...

# %%
pd.DataFrame(response.json()['stories'])
# Out:
#   resourceType     card                                              title  \
# 0        Story  article  Ringgit Bulls Watch Central Bank Support as Ne...
# 1        Story  article  Ueda Faces Fallout Risk as BOJ Mulls Yields, P...
# 2        Story  article  S&P 500 Extends Slide From Its July Peak to 10...
# 3        Story  article  Fed, Geopolitics Threaten Dollar’s Seasonal Ye...
# 4        Story  article  Tech Giants Signal Rebound as Amazon, Intel Ra...
# 5        Story  article  Turkey Delivers Another Big Rate Hike as Infla...
# 6        Story  article  Nigeria Plans New FX Rules in Hopes of Naira R...
# 7        Story  article  Russia Hikes Interest Rates Despite World’s Bi...
# 8        Story  article  Germany to Pass Japan as Third-Largest Economy...
# 9        Story  article  Yen Weakens Close to Three-Decade Low Against ...
#
#     published      internalID  \
# 0  1698624192  S34DXNDWRGG001
# 1  1698637898  S2YG04T0G1KW01
# 2  1698438328  S33YVFDWLU6801
# ...

# %%
pd.DataFrame(response.json()['stories']).shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8110264a3853> in <cell line: 1>()
# ----> 1 pd.DataFrame(response.json()['stories']).shape
#
# NameError: name 'pd' is not defined

# %%
import requests

url = "https://cricbuzz-cricket.p.rapidapi.com/matches/v1/recent"

headers = {
	"X-RapidAPI-Key": "d0d5b4c390msh1b9e671fe6b1ebcp1767eejsn31408039d516",
	"X-RapidAPI-Host": "cricbuzz-cricket.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'typeMatches': [{'matchType': 'International', 'seriesMatches': [{'seriesAdWrapper': {'seriesId': 6732, 'seriesName': 'ICC Cricket World Cup 2023', 'matches': [{'matchInfo': {'matchId': 75651, 'seriesId': 6732, 'seriesName': 'ICC Cricket World Cup 2023', 'matchDesc': 'Final', 'matchFormat': 'ODI', 'startDate': '1700382600000', 'endDate': '1700411400000', 'state': 'Complete', 'status': 'Australia won by 6 wkts', 'team1': {'teamId': 2, 'teamName': 'India', 'teamSName': 'IND', 'imageId': 172115}, 'team2': {'teamId': 4, 'teamName': 'Australia', 'teamSName': 'AUS', 'imageId': 172117}, 'venueInfo': {'id': 50, 'ground': 'Narendra Modi Stadium', 'city': 'Ahmedabad', 'timezone': '+05:30', 'latitude': '23.091785', 'longitude': '72.597465'}, 'currBatTeamId': 4, 'seriesStartDt': '1696464000000', 'seriesEndDt': '1700524800000', 'isTimeAnnounced': True, 'stateTitle': 'AUS Won', 'isFantasyEnabled': True}, 'matchScore': {'team1Score': {'inngs1': {'inningsId': 1, 'runs': 240, 'wickets': 10, 'overs':
# ...

# %%
import pandas as pd

df = pd.DataFrame(response.json()['typeMatches'])

# %%
df.Seties
# Out:
#        matchType                                      seriesMatches
# 0  International  [{'seriesAdWrapper': {'seriesId': 6732, 'serie...
# 1         League  [{'seriesAdWrapper': {'seriesId': 7243, 'serie...
# 2       Domestic  [{'seriesAdWrapper': {'seriesId': 6718, 'serie...
# 3          Women  [{'seriesAdWrapper': {'seriesId': 6850, 'serie...
