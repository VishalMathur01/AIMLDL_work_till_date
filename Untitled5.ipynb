# %%
print("hello world")
# Out:
# hello world

# %%
# prompt: generate a python code for summition of two nubmers

print("hello world")

def sum_two_numbers(a, b):
  """
  This function takes two numbers as input and returns their sum.
  """
  return a + b

# Example usage
a = 5
b = 6

sum_of_two_numbers = sum_two_numbers(a, b)

print(f"The sum of {a} and {b} is: {sum_of_two_numbers}")
# Out:
# hello world
# The sum of 5 and 6 is: 11
