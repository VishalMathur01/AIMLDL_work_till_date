# %%
napunshak = ["cancer"]
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
test = []

webpage = requests.get("https://www.ncbi.nlm.nih.gov/pmc/?term=cancer").text
soup_1 = BeautifulSoup(webpage, 'lxml')
# Out:
# /usr/local/lib/python3.10/dist-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %%
a = soup_1.find_all('dd')

# %%
a
# Out:
# [<dd>PMC6494975</dd>,
#  <dd>PMC10486581</dd>,
#  <dd>PMC10488320</dd>,
#  <dd>PMC9450413</dd>,
#  <dd>PMC5811185</dd>,
#  <dd>PMC6835610</dd>,
#  <dd>PMC6237355</dd>,
#  <dd>PMC9820434</dd>,
#  <dd>PMC8219377</dd>,
#  <dd>PMC7794669</dd>,
#  <dd>PMC7430217</dd>,
#  <dd>PMC5473951</dd>,
#  <dd>PMC8748501</dd>,
#  <dd>PMC7700753</dd>,
#  <dd>PMC8738100</dd>,
#  <dd>PMC7497309</dd>,
#  <dd>PMC9252913</dd>,
#  <dd>PMC8980946</dd>,
#  <dd>PMC9731832</dd>,
#  <dd>PMC4568174</dd>]

# %%
pmc_id = []
for i in soup_1.find_all("dd"):
  pmc_id.append(i.text)

# %%
pmc_id
# Out:
# ['PMC6494975',
#  'PMC10486581',
#  'PMC10488320',
#  'PMC9450413',
#  'PMC5811185',
#  'PMC6835610',
#  'PMC6237355',
#  'PMC9820434',
#  'PMC8219377',
#  'PMC7794669',
#  'PMC7430217',
#  'PMC5473951',
#  'PMC8748501',
#  'PMC7700753',
#  'PMC8738100',
#  'PMC7497309',
#  'PMC9252913',
#  'PMC8980946',
#  'PMC9731832',
#  'PMC4568174']

# %%
webpage = requests.get("https://www.ncbi.nlm.nih.gov/pmc/?term=cancer").text
soup = BeautifulSoup(webpage, 'lxml')
a_lot = int(input("Enter the amount thy fat pig: "))
pmc_id = []
for j in range(0, a_lot):
  for i in soup_1.find_all("dd"):
    pmc_id.append(i.text)
  webpage = requests.get("https://www.ncbi.nlm.nih.gov/pmc/?term=cancer#").text
  soup = BeautifulSoup(webpage, 'lxml')
# Out:
# Enter the amount thy fat pig: 2

# %%
pmc_id
# Out:
# ['PMC6494975',
#  'PMC10486581',
#  'PMC10488320',
#  'PMC9450413',
#  'PMC5811185',
#  'PMC6835610',
#  'PMC6237355',
#  'PMC9820434',
#  'PMC8219377',
#  'PMC7794669',
#  'PMC7430217',
#  'PMC5473951',
#  'PMC8748501',
#  'PMC7700753',
#  'PMC8738100',
#  'PMC7497309',
#  'PMC9252913',
#  'PMC8980946',
#  'PMC9731832',
#  'PMC4568174',
#  'PMC6494975',
#  'PMC10486581',
#  'PMC10488320',
#  'PMC9450413',
#  'PMC5811185',
#  'PMC6835610',
#  'PMC6237355',
#  'PMC9820434',
#  'PMC8219377',
#  'PMC7794669',
#  'PMC7430217',
#  'PMC5473951',
#  'PMC8748501',
#  'PMC7700753',
#  'PMC8738100',
#  'PMC7497309',
#  'PMC9252913',
#  'PMC8980946',
#  'PMC9731832',
#  'PMC4568174']

# %%
len(pmc_id)
# Out:
# 40

# %%
webpage = requests.get("https://www.youtube.com/pewdiepie/videos").text
soup = BeautifulSoup(webpage, 'lxml')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"}

# %%
webpage = requests.get("https://www.youtube.com/pewdiepie/videos", headers = headers).text
soup = BeautifulSoup(webpage, 'lxml')
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html darker-dark-theme="" darker-dark-theme-deprecate="" lang="en" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" system-icons="" typography="" typography-spacing=""><head><script data-id="_gd" nonce="fURTJvTCgYTVOFPApqPF7Q">window.WIZ_global_data = {"MuJWjd":false,"nQyAE":{},"oxN3nb":{"1":false}};</script><meta content="ApvK67ociHgr2egd6c2ZjrfPuRs8BHcvSggogIOPQNH7GJ3cVlyJ1NOq/COCdj0+zxskqHt9HgLLETc8qqD+vwsAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2OTUxNjc5OTksImlzU3ViZG9tYWluIjp0cnVlfQ==" http-equiv="origin-trial"/><script nonce="fURTJvTCgYTVOFPApqPF7Q">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else{var k;for(k in a[0])ytcfg.d()[k]=a[0][k]}}};
# ...

# %%
soup.find("img")
