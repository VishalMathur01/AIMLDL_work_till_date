# %%
import cv2

# %%
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/48637754-8278-4914-8b6a-0f5f135cf2ff.jfif')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=720x1280>

# %%
cv2_imshow(cv2.resize(img, (256, 425)))
# Out:
# <PIL.Image.Image image mode=RGB size=256x425>

# %%
cv2_imshow(cv2.medianBlur(cv2.resize(img, (256, 425)), 3))
# Out:
# <PIL.Image.Image image mode=RGB size=256x425>
