# %% [markdown]
# two main reason
# * numpy is written in c
# * great way to represent data so machines can understand it

# %% [markdown]
# why numpy
# * it's fast
# * behind the scenes optimization in C
# * vectorization via broadcasting (avoiding loops)
# * Backbone of other python scientific packages

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # numpy data types
